# %%
using CLOUD
using LinearAlgebra
using Markdown
sequence_path = "../results/advection_dgmulti_1D_refine_p3_upwind/"
analysis_path = new_path(string(sequence_path,"refinement_analysis/"))

a = 1.0  # advection velocity
A = 1.0  # amplitude
L = 1.0  # domain length
k = 8*π/L  # wave number
T = 1*L/a  # end time
initial_data = InitialDataSine(A,k)
conservation_law = linear_advection_equation(a,λ=1.0);
# Out:
# ┌ Info: Precompiling CLOUD [fb992021-99c7-4c2d-a14b-5e48ac4045b2]
# └ @ Base loading.jl:1342

# %%
refinement_analysis = RefinementAnalysis(initial_data, sequence_path, analysis_path);
refinement_results = analyze(refinement_analysis);
save_analysis(refinement_analysis, refinement_results)
plot_analysis(refinement_analysis, refinement_results)

# %%
Markdown.parse(tabulate_analysis(refinement_results, print_latex=false))
# Out:
#    M Conservation Metric Energy Metric    L² Error   Order
#   –– ––––––––––––––––––– ––––––––––––– ––––––––––– –––––––
#    2         2.08167e-17  -6.42296e-01 7.60109e-01
#    4        -4.33681e-17  -5.42385e-01 7.09472e-01 0.09946
#    8        -1.80411e-16  -3.32956e-02 3.18013e-02 4.47959
#   16         7.63278e-17  -3.76836e-04 1.00493e-03 4.98392
#   32        -5.55112e-17  -3.19044e-06 6.06780e-05 4.04977
#   64        -2.78857e-16  -2.54452e-08 3.78474e-06 4.00291
