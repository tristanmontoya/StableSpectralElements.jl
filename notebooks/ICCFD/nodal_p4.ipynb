# %%
using CLOUD
using LinearAlgebra
using Markdown
sequence_path = ["../../results/run_2/advection_CollapsedSEM_p4M2l1_20220616_171001/", "../../results/run_2/advection_CollapsedSEM_p4M2l0_20220616_171001/"]
n = length(sequence_path)
analysis_path = [new_path(string(sequence_path[i],"refinement_analysis/")) 
    for i in 1:n]
(conservation_law, spatial_discretization, 
    initial_data, form, tspan, strategy) = load_project(
        string(sequence_path[1],"grid_1/"));

# %%
refinement_analysis = [RefinementAnalysis(initial_data, sequence_path[i], analysis_path[i]) for i in 1:n]
refinement_results = [analyze(refinement_analysis[i], 5) for i in 1:n]
plot_analysis(refinement_analysis[1], refinement_results[1])

# %%
plot_analysis(refinement_analysis[2], refinement_results[2])

# %%
tabulate_analysis_for_paper((refinement_results[1],refinement_results[2]))
# Out:
# \begin{table}
#   \begin{tabular}{rrrrrrrrr}
#     \toprule
#     \textbf{$N_e$} & \textbf{Conservation Metric} &  & \textbf{Energy Metric} &  & \textbf{$L^2$ Error} &  & \textbf{Order} &  \\\midrule
#     8 & 5.725e-17 & -2.099e-16 & -4.145e-02 & -2.175e-11 & 9.955e-02 & 2.531e-01 &  &  \\
#     32 & -9.845e-16 & -1.046e-15 & -2.591e-03 & -6.500e-14 & 1.536e-02 & 4.280e-02 & 2.69661 & 2.56367 \\
#     128 & -3.837e-16 & -3.427e-16 & -1.412e-05 & 2.276e-15 & 5.764e-04 & 4.651e-03 & 4.73549 & 3.2021 \\
#     512 & -3.121e-15 & -3.035e-15 & -3.772e-08 & 4.219e-15 & 1.750e-05 & 1.751e-04 & 5.04150 & 4.7314 \\
#     2048 & -1.756e-14 & -1.749e-14 & -7.975e-11 & 3.647e-14 & 5.660e-07 & 7.911e-06 & 4.95060 & 4.468 \\\bottomrule
#   \end{tabular}
# \end{table}
