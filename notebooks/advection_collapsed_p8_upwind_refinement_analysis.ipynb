# %%
using CLOUD
using LinearAlgebra
using Markdown
sequence_path = "../results/advection_CollapsedSEM_p8l1_20220611_181310/"
analysis_path = new_path(string(sequence_path,"refinement_analysis/"))


(conservation_law, spatial_discretization, 
    initial_data, form, tspan, strategy) = load_project(
        string(sequence_path,"grid_1/"));
# Out:
# ┌ Info: Installing pyqt package to avoid buggy tkagg backend.
# └ @ PyPlot /Users/tristanmontoya/.julia/packages/PyPlot/XaELc/src/init.jl:118

# %%
refinement_analysis = RefinementAnalysis(initial_data, sequence_path, analysis_path)
refinement_results = analyze(refinement_analysis, 4)
save_analysis(refinement_analysis, refinement_results)
plot_analysis(refinement_analysis, refinement_results)

# %%
println(Markdown.parse(tabulate_analysis(refinement_results, print_latex=true)))
# Out:
# \begin{table}
#   \begin{tabular}{rrrrr}
#     \toprule
#     \textbf{Elements} & \textbf{Conservation Metric} & \textbf{Energy Metric} & \textbf{$L^2$ Error} & \textbf{Order} \\\midrule
#     8 & 5.25621e-16 & -6.63521e-10 & 2.53051e-01 &  \\
#     32 & -2.19529e-15 & -1.86573e-12 & 4.28021e-02 & 2.56367 \\
#     128 & -3.47611e-15 & -5.82867e-16 & 4.65092e-03 & 3.20210 \\
#     512 & -9.08214e-15 & 1.94844e-14 & 1.75084e-04 & 4.73140 \\\bottomrule
#   \end{tabular}
# \end{table}
# |
# Elements | Conservation Metric | Energy Metric |    L² Error |   Order |
# | --------:| -------------------:| -------------:| -----------:| -------:|
# |        8 |         5.25621e-16 |  -6.63521e-10 | 2.53051e-01 |         |
# |       32 |        -2.19529e-15 |  -1.86573e-12 | 4.28021e-02 | 2.56367 |
# |      128 |        -3.47611e-15 |  -5.82867e-16 | 4.65092e-03 | 3.20210 |
# |      512 |        -9.08214e-15 |   1.94844e-14 | 1.75084e-04 | 4.73140 |
