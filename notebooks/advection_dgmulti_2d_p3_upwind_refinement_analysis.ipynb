# %%
using CLOUD
using LinearAlgebra
using Markdown
sequence_path = "../results/advection_dgmulti_2D_refine_p3_upwind/"
analysis_path = new_path(string(sequence_path,"refinement_analysis/"))


θ = π/4
a = sqrt(2)
A = 1.0  # amplitude
L = 1.0  # domain length
k = (2*π/L, 2*π/L)  # wave number
T = 1.0/(a*max(abs(cos(θ)),abs(cos(θ))))  # end time
initial_data = InitialDataSine(A,k)
conservation_law = linear_advection_equation((a*cos(θ),a*sin(θ)),λ=0.0);

# %%
refinement_analysis = RefinementAnalysis(initial_data, sequence_path, analysis_path)
refinement_results = analyze(refinement_analysis)
save_analysis(refinement_analysis, refinement_results)
plot_analysis(refinement_analysis, refinement_results)

# %%
Markdown.parse(tabulate_analysis(refinement_results, print_latex=false))
# Out:
#      M Conservation Metric Energy Metric    L² Error   Order
#   –––– ––––––––––––––––––– ––––––––––––– ––––––––––– –––––––
#      4        -9.02056e-17  -7.75503e-02 1.40081e-01
#     16         6.41848e-17  -8.49804e-03 3.43961e-02 2.02595
#     64         6.96058e-17  -1.73658e-04 2.31203e-03 3.89501
#    256         5.60343e-16  -1.73699e-06 1.57590e-04 3.87491
#   1024         2.14264e-15  -1.49547e-08 1.03326e-05 3.93091
#   4096         8.21786e-15  -1.27109e-10 6.55919e-07 3.97754
